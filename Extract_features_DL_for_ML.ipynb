# %%
# import torch functions
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
import torch.nn.functional as F

# import torchvision functions
import torchvision
from torchvision.models import vgg16
import torchvision.utils as vutils
from torchvision import datasets, transforms, utils
import torchvision.transforms as T

# import other functions
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
from itertools import islice
from PIL import Image
import time 
import torchsummary
from sklearn.metrics import accuracy_score

# %%
original_dataset_dir = r'C:\Users\pauli\Documents\M2\ML et DL\projet\Git\DamageDetection'

# %%
train_damage_dir = original_dataset_dir + '/train_another/damage'
validation_damage_dir = original_dataset_dir + '/validation_another/damage'
test_damage_dir = original_dataset_dir + '/test/damage'

train_nodamage_dir = original_dataset_dir + '/train_another/no_damage'
validation_nodamage_dir = original_dataset_dir + '/validation_another/no_damage'
test_nodamage_dir = original_dataset_dir + '/test/no_damage'

# %%
print('total training damage images: ',len(os.listdir(train_damage_dir)))
print('total validation damage images: ',len(os.listdir(validation_damage_dir)))
print('total test damage images: ',len(os.listdir(test_damage_dir)))

print('total training no damage images: ',len(os.listdir(train_nodamage_dir)))
print('total validation no damage images: ',len(os.listdir(validation_nodamage_dir)))
print('total test no damage images: ',len(os.listdir(test_nodamage_dir)))
# Out:
# total training damage images:  5000
# total validation damage images:  1000
# total test damage images:  1000
# total training no damage images:  5000
# total validation no damage images:  1000
# total test no damage images:  1000

# %%
# fonction pour entrainer les modeles

def fit(model, train_loader, val_loader, epochs, steps_per_epoch, validation_steps):
    epoch_nums = []
    training_acc = []
    validation_acc = []
    training_loss = []
    validation_loss = []
    
    for epoch in range(epochs):
        accuracy = 0.0
        running_loss = 0.0
        start_time = time.time()
        # Entraîne le modèle sur les données d'entraînement
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Entraîne le modèle sur un lot de données
            outputs = model(images)
            loss = criterion(outputs, labels.float().view(-1,1))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            #running_loss += loss.item()
            accuracy += (torch.round(outputs) == labels.float().view(-1,1)).sum().item() / len(labels)
            running_loss += loss.item()
        
            if (i+1) % steps_per_epoch == 0:
                break
        train_loss = running_loss / steps_per_epoch
        train_acc = accuracy / steps_per_epoch 
                
        
        model.eval()
        with torch.no_grad():
            val_loss = 0
            val_acc = 0
            for i, (images, labels) in enumerate(val_loader):
                outputs = model(images)
                val_loss += criterion(outputs, labels.float().view(-1,1)).item()
                _, predicted = torch.max(outputs.data, 1)
                val_acc += (torch.round(outputs) == labels.float().view(-1,1)).sum().item() / len(labels)
                
                if i >= validation_steps:
                    break
        
        val_loss /= validation_steps
        val_acc /= validation_steps 

        epoch_nums.append(epoch+1)
        training_loss.append(train_loss)
        validation_loss.append(val_loss)
        training_acc.append(train_acc)
        validation_acc.append(val_acc)
        
        elapsed_time = time.time() - start_time
        print(elapsed_time)
        print(f"Epoch [{epoch+1}/{epochs}], Time : {elapsed_time:.4f}, Train Loss: {loss.item():.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")
        
    return {
        'training_acc': training_acc,
        'validation_acc': validation_acc,
        'training_loss': training_loss,
        'validation_loss': validation_loss
    }

def fit_transfer(model, train_features, train_labels, val_features, val_labels, epochs, steps_per_epoch, validation_steps):
    epoch_nums = []
    training_acc = []
    validation_acc = []
    training_loss = []
    validation_loss = []
    
    for epoch in range(epochs):
        accuracy = 0.0
        running_loss = 0.0
        start_time = time.time()
        # Entraîne le modèle sur les données d'entraînement
        model.train()
        
        # Entraîne le modèle sur un lot de données
        outputs = model(train_features)
        loss = criterion(outputs, train_labels.float().view(-1,1))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        #running_loss += loss.item()
        accuracy += (torch.round(outputs) == train_labels.float().view(-1,1)).sum().item() / len(train_labels)
        running_loss += loss.item()
            
        train_loss = running_loss 
        train_acc = accuracy
        
        model.eval()
        with torch.no_grad():
            val_loss = 0
            val_acc = 0
            outputs = model(val_features)
            val_loss += criterion(outputs, val_labels.float().view(-1,1)).item()
            _, predicted = torch.max(outputs.data, 1)
            val_acc += (torch.round(outputs) == val_labels.float().view(-1,1)).sum().item() / len(val_labels)

        epoch_nums.append(epoch+1)
        training_loss.append(train_loss)
        validation_loss.append(val_loss)
        training_acc.append(train_acc)
        validation_acc.append(val_acc)
        
        elapsed_time = time.time() - start_time
        print(elapsed_time)
        print(f"Epoch [{epoch+1}/{epochs}], Time : {elapsed_time:.4f}, Train Loss: {loss.item():.4f}, Train Accuracy: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")
        
    return {
        'training_acc': training_acc,
        'validation_acc': validation_acc,
        'training_loss': training_loss,
        'validation_loss': validation_loss
    }


# Extraire les caractéristiques des images
def extract_features(data_loader, sample_count, conv_base, batch_size, last_size):
    features = torch.zeros(sample_count, 512, last_size, last_size)
    labels = torch.zeros(sample_count, dtype=torch.long)
    
    i = 0
    for inputs_batch, labels_batch in data_loader:
        with torch.no_grad():
            features_batch = conv_base(inputs_batch)
        features[i * batch_size: (i + 1) * batch_size] = features_batch
        labels[i * batch_size: (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels

# %% [markdown]
# # Transcription du modele vgg16 en pytorch

# %% [markdown]
# Ici nous ne faisons que la traduction du code keras effectué par Cao

# %% [markdown]
# ## Récupération des features de vgg16

# %%
# Chargment du modèle pré-entraîné ResNet18
modelvgg16 = torchvision.models.vgg16(pretrained=True)
torchsummary.summary(modelvgg16, (3,150,150))

# Extraction des caractéristiques
modelvgg16 = modelvgg16.features[:31] # nombre de caractéristiques en entrée de la couche fc
torchsummary.summary(modelvgg16, (3,150,150))
# Out:
# C:\Users\pauli\anaconda3\envs\DL\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 150, 150]           1,792
#               ReLU-2         [-1, 64, 150, 150]               0
#             Conv2d-3         [-1, 64, 150, 150]          36,928
#               ReLU-4         [-1, 64, 150, 150]               0
#          MaxPool2d-5           [-1, 64, 75, 75]               0
#             Conv2d-6          [-1, 128, 75, 75]          73,856
#               ReLU-7          [-1, 128, 75, 75]               0
#             Conv2d-8          [-1, 128, 75, 75]         147,584
#               ReLU-9          [-1, 128, 75, 75]               0
#         MaxPool2d-10          [-1, 128, 37, 37]               0
#            Conv2d-11          [-1, 256, 37, 37]         295,168
#              ReLU-12          [-1, 256, 37, 37]               0
#            Conv2d-13          [-1, 256, 37, 37]         590,080
#              ReLU-14          [-1, 256, 37, 37]               0
#            Conv2d-15          [-1, 256, 37, 37]         590,080
#              ReLU-16          [-1, 256, 37, 37]               0
#         MaxPool2d-17          [-1, 256, 18, 18]               0
#            Conv2d-18          [-1, 512, 18, 18]       1,180,160
#              ReLU-19          [-1, 512, 18, 18]               0
#            Conv2d-20          [-1, 512, 18, 18]       2,359,808
#              ReLU-21          [-1, 512, 18, 18]               0
#            Conv2d-22          [-1, 512, 18, 18]       2,359,808
#              ReLU-23          [-1, 512, 18, 18]               0
#         MaxPool2d-24            [-1, 512, 9, 9]               0
#            Conv2d-25            [-1, 512, 9, 9]       2,359,808
#              ReLU-26            [-1, 512, 9, 9]               0
#            Conv2d-27            [-1, 512, 9, 9]       2,359,808
#              ReLU-28            [-1, 512, 9, 9]               0
#            Conv2d-29            [-1, 512, 9, 9]       2,359,808
#              ReLU-30            [-1, 512, 9, 9]               0
#         MaxPool2d-31            [-1, 512, 4, 4]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 96.93
# Params size (MB): 527.79
# Estimated Total Size (MB): 624.98
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 150, 150]           1,792
#               ReLU-2         [-1, 64, 150, 150]               0
#             Conv2d-3         [-1, 64, 150, 150]          36,928
#               ReLU-4         [-1, 64, 150, 150]               0
#          MaxPool2d-5           [-1, 64, 75, 75]               0
#             Conv2d-6          [-1, 128, 75, 75]          73,856
#               ReLU-7          [-1, 128, 75, 75]               0
#             Conv2d-8          [-1, 128, 75, 75]         147,584
#               ReLU-9          [-1, 128, 75, 75]               0
#         MaxPool2d-10          [-1, 128, 37, 37]               0
#            Conv2d-11          [-1, 256, 37, 37]         295,168
#              ReLU-12          [-1, 256, 37, 37]               0
#            Conv2d-13          [-1, 256, 37, 37]         590,080
#              ReLU-14          [-1, 256, 37, 37]               0
#            Conv2d-15          [-1, 256, 37, 37]         590,080
#              ReLU-16          [-1, 256, 37, 37]               0
#         MaxPool2d-17          [-1, 256, 18, 18]               0
#            Conv2d-18          [-1, 512, 18, 18]       1,180,160
#              ReLU-19          [-1, 512, 18, 18]               0
#            Conv2d-20          [-1, 512, 18, 18]       2,359,808
#              ReLU-21          [-1, 512, 18, 18]               0
#            Conv2d-22          [-1, 512, 18, 18]       2,359,808
#              ReLU-23          [-1, 512, 18, 18]               0
#         MaxPool2d-24            [-1, 512, 9, 9]               0
#            Conv2d-25            [-1, 512, 9, 9]       2,359,808
#              ReLU-26            [-1, 512, 9, 9]               0
#            Conv2d-27            [-1, 512, 9, 9]       2,359,808
#              ReLU-28            [-1, 512, 9, 9]               0
#            Conv2d-29            [-1, 512, 9, 9]       2,359,808
#              ReLU-30            [-1, 512, 9, 9]               0
#         MaxPool2d-31            [-1, 512, 4, 4]               0
# ================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 96.55
# Params size (MB): 56.13
# Estimated Total Size (MB): 152.94
# ----------------------------------------------------------------

# %%
datagen = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size=20

train_dataset = ImageFolder(original_dataset_dir+'/train_another', transform=datagen)
train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=4, shuffle=True)

val_dataset = ImageFolder(original_dataset_dir+'/validation_another', transform=datagen)
val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=4, shuffle=True)

test_dataset = ImageFolder(original_dataset_dir+'/test_another', transform=datagen)
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=4, shuffle=True)

# %%
train_features, train_labels = extract_features(train_loader, 10000, modelvgg16, batch_size=batch_size,last_size=4)
validation_features, validation_labels = extract_features(val_loader, 2000, modelvgg16, batch_size=batch_size,last_size=4)
test_features, test_labels = extract_features(test_loader, 2000, modelvgg16, batch_size=batch_size,last_size=4)

# Reformater les caractéristiques pour être de forme (sample_count, 8192)
train_features = train_features.view(10000, 4 * 4 * 512)
validation_features = validation_features.view(2000, 4 * 4 * 512)
test_features = test_features.view(2000, 4 * 4 * 512)

# %% [markdown]
# ## VGG16 sur un CNN simple

# %%
class BinaryClassifier(nn.Module):
    def __init__(self):
        super(BinaryClassifier, self).__init__()
        self.fc1 = nn.Linear(4 * 4 * 512, 256) 
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, 1)

    def forward(self, x):
        x = x.view(x.shape[0],-1)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc2(x))
        return x
BinaryClassifier = BinaryClassifier()

criterion = nn.BCELoss()
optimizer = optim.RMSprop(BinaryClassifier.parameters(), lr=0.0001)

# %%
# Initialisation des paramètres 
steps_per_epoch = 100
epochs = 100
validation_steps = 50

history = fit_transfer(BinaryClassifier, train_features, train_labels, validation_features, validation_labels, epochs, steps_per_epoch, validation_steps)
# Out:
# 0.30835533142089844
# Epoch [1/100], Time : 0.3084, Train Loss: 0.6920, Train Accuracy: 0.5131, Validation Loss: 0.7058, Validation Accuracy: 0.6165
# 0.30707526206970215
# Epoch [2/100], Time : 0.3071, Train Loss: 0.6959, Train Accuracy: 0.6283, Validation Loss: 0.7119, Validation Accuracy: 0.5445
# 0.30626463890075684
# Epoch [3/100], Time : 0.3063, Train Loss: 0.7155, Train Accuracy: 0.5554, Validation Loss: 0.5148, Validation Accuracy: 0.8010
# 0.32716894149780273
# Epoch [4/100], Time : 0.3272, Train Loss: 0.5093, Train Accuracy: 0.8074, Validation Loss: 0.4446, Validation Accuracy: 0.8310
# 0.27551770210266113
# Epoch [5/100], Time : 0.2755, Train Loss: 0.4373, Train Accuracy: 0.8378, Validation Loss: 0.3990, Validation Accuracy: 0.8455
# 0.35808682441711426
# Epoch [6/100], Time : 0.3581, Train Loss: 0.3904, Train Accuracy: 0.8496, Validation Loss: 0.3740, Validation Accuracy: 0.8510
# 0.33693504333496094
# Epoch [7/100], Time : 0.3369, Train Loss: 0.3611, Train Accuracy: 0.8582, Validation Loss: 0.3558, Validation Accuracy: 0.8630
# 0.29622721672058105
# Epoch [8/100], Time : 0.2962, Train Loss: 0.3418, Train Accuracy: 0.8671, Validation Loss: 0.3466, Validation Accuracy: 0.8625
# 0.2656819820404053
# Epoch [9/100], Time : 0.2657, Train Loss: 0.3282, Train Accuracy: 0.8714, Validation Loss: 0.3415, Validation Accuracy: 0.8650
# 0.316514253616333
# Epoch [10/100], Time : 0.3165, Train Loss: 0.3243, Train Accuracy: 0.8735, Validation Loss: 0.3625, Validation Accuracy: 0.8465
# 0.3268861770629883
# Epoch [11/100], Time : 0.3269, Train Loss: 0.3371, Train Accuracy: 0.8665, Validation Loss: 0.3586, Validation Accuracy: 0.8505
# 0.3138132095336914
# Epoch [12/100], Time : 0.3138, Train Loss: 0.3390, Train Accuracy: 0.8572, Validation Loss: 0.3712, Validation Accuracy: 0.8410
# 0.30908703804016113
# Epoch [13/100], Time : 0.3091, Train Loss: 0.3417, Train Accuracy: 0.8593, Validation Loss: 0.3280, Validation Accuracy: 0.8665
# 0.32549428939819336
# Epoch [14/100], Time : 0.3255, Train Loss: 0.3063, Train Accuracy: 0.8781, Validation Loss: 0.3171, Validation Accuracy: 0.8720
# 0.29668498039245605
# Epoch [15/100], Time : 0.2967, Train Loss: 0.2885, Train Accuracy: 0.8928, Validation Loss: 0.2981, Validation Accuracy: 0.8865
# 0.2748725414276123
# Epoch [16/100], Time : 0.2749, Train Loss: 0.2709, Train Accuracy: 0.9000, Validation Loss: 0.2927, Validation Accuracy: 0.8895
# 0.3359532356262207
# Epoch [17/100], Time : 0.3360, Train Loss: 0.2622, Train Accuracy: 0.9053, Validation Loss: 0.2845, Validation Accuracy: 0.8935
# 0.286923885345459
# Epoch [18/100], Time : 0.2869, Train Loss: 0.2564, Train Accuracy: 0.9058, Validation Loss: 0.2820, Validation Accuracy: 0.8965
# 0.3058302402496338
# Epoch [19/100], Time : 0.3058, Train Loss: 0.2500, Train Accuracy: 0.9107, Validation Loss: 0.2760, Validation Accuracy: 0.8980
# 0.295727014541626
# Epoch [20/100], Time : 0.2957, Train Loss: 0.2443, Train Accuracy: 0.9126, Validation Loss: 0.2744, Validation Accuracy: 0.9000
# 0.2761075496673584
# Epoch [21/100], Time : 0.2761, Train Loss: 0.2396, Train Accuracy: 0.9157, Validation Loss: 0.2694, Validation Accuracy: 0.9000
# 0.3154723644256592
# Epoch [22/100], Time : 0.3155, Train Loss: 0.2365, Train Accuracy: 0.9149, Validation Loss: 0.2687, Validation Accuracy: 0.9010
# 0.37475037574768066
# Epoch [23/100], Time : 0.3748, Train Loss: 0.2328, Train Accuracy: 0.9189, Validation Loss: 0.2649, Validation Accuracy: 0.9010
# 0.2670762538909912
# Epoch [24/100], Time : 0.2671, Train Loss: 0.2297, Train Accuracy: 0.9174, Validation Loss: 0.2653, Validation Accuracy: 0.9010
# 0.3257620334625244
# Epoch [25/100], Time : 0.3258, Train Loss: 0.2248, Train Accuracy: 0.9224, Validation Loss: 0.2611, Validation Accuracy: 0.9010
# 0.28278231620788574
# Epoch [26/100], Time : 0.2828, Train Loss: 0.2233, Train Accuracy: 0.9198, Validation Loss: 0.2630, Validation Accuracy: 0.9015
# 0.3257029056549072
# Epoch [27/100], Time : 0.3257, Train Loss: 0.2219, Train Accuracy: 0.9237, Validation Loss: 0.2591, Validation Accuracy: 0.9020
# 0.30559396743774414
# Epoch [28/100], Time : 0.3056, Train Loss: 0.2194, Train Accuracy: 0.9199, Validation Loss: 0.2621, Validation Accuracy: 0.8985
# 0.32607078552246094
# Epoch [29/100], Time : 0.3261, Train Loss: 0.2173, Train Accuracy: 0.9234, Validation Loss: 0.2579, Validation Accuracy: 0.9020
# 0.3063385486602783
# Epoch [30/100], Time : 0.3063, Train Loss: 0.2149, Train Accuracy: 0.9197, Validation Loss: 0.2597, Validation Accuracy: 0.9000
# 0.30411410331726074
# Epoch [31/100], Time : 0.3041, Train Loss: 0.2150, Train Accuracy: 0.9265, Validation Loss: 0.2537, Validation Accuracy: 0.9025
# 0.2549753189086914
# Epoch [32/100], Time : 0.2550, Train Loss: 0.2116, Train Accuracy: 0.9221, Validation Loss: 0.2547, Validation Accuracy: 0.9030
# 0.31613588333129883
# Epoch [33/100], Time : 0.3161, Train Loss: 0.2086, Train Accuracy: 0.9301, Validation Loss: 0.2492, Validation Accuracy: 0.9035
# 0.306185245513916
# Epoch [34/100], Time : 0.3062, Train Loss: 0.2046, Train Accuracy: 0.9243, Validation Loss: 0.2499, Validation Accuracy: 0.9050
# 0.3345942497253418
# Epoch [35/100], Time : 0.3346, Train Loss: 0.2032, Train Accuracy: 0.9309, Validation Loss: 0.2436, Validation Accuracy: 0.9050
# 0.30799055099487305
# Epoch [36/100], Time : 0.3080, Train Loss: 0.1969, Train Accuracy: 0.9299, Validation Loss: 0.2430, Validation Accuracy: 0.9095
# 0.3366508483886719
# Epoch [37/100], Time : 0.3367, Train Loss: 0.1961, Train Accuracy: 0.9339, Validation Loss: 0.2390, Validation Accuracy: 0.9070
# 0.30614519119262695
# Epoch [38/100], Time : 0.3061, Train Loss: 0.1907, Train Accuracy: 0.9323, Validation Loss: 0.2388, Validation Accuracy: 0.9120
# 0.3260679244995117
# Epoch [39/100], Time : 0.3261, Train Loss: 0.1890, Train Accuracy: 0.9385, Validation Loss: 0.2355, Validation Accuracy: 0.9100
# 0.3746504783630371
# Epoch [40/100], Time : 0.3747, Train Loss: 0.1853, Train Accuracy: 0.9355, Validation Loss: 0.2351, Validation Accuracy: 0.9130
# 0.3177051544189453
# Epoch [41/100], Time : 0.3177, Train Loss: 0.1833, Train Accuracy: 0.9382, Validation Loss: 0.2325, Validation Accuracy: 0.9115
# 0.33711934089660645
# Epoch [42/100], Time : 0.3371, Train Loss: 0.1818, Train Accuracy: 0.9399, Validation Loss: 0.2319, Validation Accuracy: 0.9145
# 0.31543993949890137
# Epoch [43/100], Time : 0.3154, Train Loss: 0.1783, Train Accuracy: 0.9421, Validation Loss: 0.2296, Validation Accuracy: 0.9120
# 0.34696245193481445
# Epoch [44/100], Time : 0.3470, Train Loss: 0.1770, Train Accuracy: 0.9416, Validation Loss: 0.2293, Validation Accuracy: 0.9160
# 0.2850508689880371
# Epoch [45/100], Time : 0.2851, Train Loss: 0.1767, Train Accuracy: 0.9415, Validation Loss: 0.2271, Validation Accuracy: 0.9150
# 0.3343219757080078
# Epoch [46/100], Time : 0.3343, Train Loss: 0.1738, Train Accuracy: 0.9418, Validation Loss: 0.2267, Validation Accuracy: 0.9180
# 0.3254680633544922
# Epoch [47/100], Time : 0.3255, Train Loss: 0.1718, Train Accuracy: 0.9425, Validation Loss: 0.2250, Validation Accuracy: 0.9155
# 0.3159627914428711
# Epoch [48/100], Time : 0.3160, Train Loss: 0.1694, Train Accuracy: 0.9425, Validation Loss: 0.2248, Validation Accuracy: 0.9180
# 0.31616926193237305
# Epoch [49/100], Time : 0.3162, Train Loss: 0.1684, Train Accuracy: 0.9450, Validation Loss: 0.2231, Validation Accuracy: 0.9155
# 0.3041503429412842
# Epoch [50/100], Time : 0.3042, Train Loss: 0.1670, Train Accuracy: 0.9440, Validation Loss: 0.2231, Validation Accuracy: 0.9185
# 0.3161337375640869
# Epoch [51/100], Time : 0.3161, Train Loss: 0.1647, Train Accuracy: 0.9461, Validation Loss: 0.2215, Validation Accuracy: 0.9160
# 0.33643460273742676
# Epoch [52/100], Time : 0.3364, Train Loss: 0.1633, Train Accuracy: 0.9442, Validation Loss: 0.2215, Validation Accuracy: 0.9190
# 0.2877156734466553
# Epoch [53/100], Time : 0.2877, Train Loss: 0.1614, Train Accuracy: 0.9470, Validation Loss: 0.2199, Validation Accuracy: 0.9165
# 0.30611753463745117
# Epoch [54/100], Time : 0.3061, Train Loss: 0.1605, Train Accuracy: 0.9472, Validation Loss: 0.2205, Validation Accuracy: 0.9165
# 0.33724045753479004
# Epoch [55/100], Time : 0.3372, Train Loss: 0.1587, Train Accuracy: 0.9468, Validation Loss: 0.2192, Validation Accuracy: 0.9170
# 0.32626771926879883
# Epoch [56/100], Time : 0.3263, Train Loss: 0.1577, Train Accuracy: 0.9486, Validation Loss: 0.2203, Validation Accuracy: 0.9170
# 0.31356096267700195
# Epoch [57/100], Time : 0.3136, Train Loss: 0.1584, Train Accuracy: 0.9483, Validation Loss: 0.2188, Validation Accuracy: 0.9180
# 0.3181185722351074
# Epoch [58/100], Time : 0.3181, Train Loss: 0.1580, Train Accuracy: 0.9476, Validation Loss: 0.2201, Validation Accuracy: 0.9170
# 0.3165934085845947
# Epoch [59/100], Time : 0.3166, Train Loss: 0.1565, Train Accuracy: 0.9480, Validation Loss: 0.2188, Validation Accuracy: 0.9185
# 0.28575730323791504
# Epoch [60/100], Time : 0.2858, Train Loss: 0.1562, Train Accuracy: 0.9467, Validation Loss: 0.2200, Validation Accuracy: 0.9155
# 0.26470208168029785
# Epoch [61/100], Time : 0.2647, Train Loss: 0.1554, Train Accuracy: 0.9484, Validation Loss: 0.2186, Validation Accuracy: 0.9160
# 0.29555845260620117
# Epoch [62/100], Time : 0.2956, Train Loss: 0.1545, Train Accuracy: 0.9473, Validation Loss: 0.2208, Validation Accuracy: 0.9160
# 0.3270590305328369
# Epoch [63/100], Time : 0.3271, Train Loss: 0.1538, Train Accuracy: 0.9495, Validation Loss: 0.2188, Validation Accuracy: 0.9165
# 0.28613853454589844
# Epoch [64/100], Time : 0.2861, Train Loss: 0.1540, Train Accuracy: 0.9463, Validation Loss: 0.2209, Validation Accuracy: 0.9145
# 0.27573728561401367
# Epoch [65/100], Time : 0.2757, Train Loss: 0.1530, Train Accuracy: 0.9497, Validation Loss: 0.2177, Validation Accuracy: 0.9160
# 0.3056914806365967
# Epoch [66/100], Time : 0.3057, Train Loss: 0.1502, Train Accuracy: 0.9486, Validation Loss: 0.2194, Validation Accuracy: 0.9155
# 0.35512375831604004
# Epoch [67/100], Time : 0.3551, Train Loss: 0.1503, Train Accuracy: 0.9510, Validation Loss: 0.2161, Validation Accuracy: 0.9170
# 0.3485143184661865
# Epoch [68/100], Time : 0.3485, Train Loss: 0.1475, Train Accuracy: 0.9499, Validation Loss: 0.2174, Validation Accuracy: 0.9160
# 0.30394721031188965
# Epoch [69/100], Time : 0.3039, Train Loss: 0.1458, Train Accuracy: 0.9530, Validation Loss: 0.2141, Validation Accuracy: 0.9175
# 0.3060567378997803
# Epoch [70/100], Time : 0.3061, Train Loss: 0.1438, Train Accuracy: 0.9507, Validation Loss: 0.2143, Validation Accuracy: 0.9160
# 0.3264634609222412
# Epoch [71/100], Time : 0.3265, Train Loss: 0.1425, Train Accuracy: 0.9524, Validation Loss: 0.2107, Validation Accuracy: 0.9190
# 0.29516148567199707
# Epoch [72/100], Time : 0.2952, Train Loss: 0.1394, Train Accuracy: 0.9532, Validation Loss: 0.2109, Validation Accuracy: 0.9180
# 0.2950451374053955
# Epoch [73/100], Time : 0.2950, Train Loss: 0.1387, Train Accuracy: 0.9553, Validation Loss: 0.2084, Validation Accuracy: 0.9200
# 0.30545711517333984
# Epoch [74/100], Time : 0.3055, Train Loss: 0.1367, Train Accuracy: 0.9553, Validation Loss: 0.2088, Validation Accuracy: 0.9195
# 0.36478281021118164
# Epoch [75/100], Time : 0.3648, Train Loss: 0.1360, Train Accuracy: 0.9557, Validation Loss: 0.2068, Validation Accuracy: 0.9210
# 0.34299135208129883
# Epoch [76/100], Time : 0.3430, Train Loss: 0.1340, Train Accuracy: 0.9577, Validation Loss: 0.2068, Validation Accuracy: 0.9215
# 0.3086864948272705
# Epoch [77/100], Time : 0.3087, Train Loss: 0.1311, Train Accuracy: 0.9577, Validation Loss: 0.2050, Validation Accuracy: 0.9210
# 0.3158869743347168
# Epoch [78/100], Time : 0.3159, Train Loss: 0.1298, Train Accuracy: 0.9585, Validation Loss: 0.2053, Validation Accuracy: 0.9230
# 0.3155677318572998
# Epoch [79/100], Time : 0.3156, Train Loss: 0.1296, Train Accuracy: 0.9588, Validation Loss: 0.2040, Validation Accuracy: 0.9220
# 0.2830183506011963
# Epoch [80/100], Time : 0.2830, Train Loss: 0.1293, Train Accuracy: 0.9573, Validation Loss: 0.2042, Validation Accuracy: 0.9235
# 0.318220853805542
# Epoch [81/100], Time : 0.3182, Train Loss: 0.1277, Train Accuracy: 0.9586, Validation Loss: 0.2031, Validation Accuracy: 0.9225
# 0.34604954719543457
# Epoch [82/100], Time : 0.3460, Train Loss: 0.1263, Train Accuracy: 0.9593, Validation Loss: 0.2034, Validation Accuracy: 0.9230
# 0.3143012523651123
# Epoch [83/100], Time : 0.3143, Train Loss: 0.1256, Train Accuracy: 0.9612, Validation Loss: 0.2023, Validation Accuracy: 0.9225
# 0.28838253021240234
# Epoch [84/100], Time : 0.2884, Train Loss: 0.1253, Train Accuracy: 0.9607, Validation Loss: 0.2028, Validation Accuracy: 0.9230
# 0.2935323715209961
# Epoch [85/100], Time : 0.2935, Train Loss: 0.1241, Train Accuracy: 0.9616, Validation Loss: 0.2018, Validation Accuracy: 0.9225
# 0.2861158847808838
# Epoch [86/100], Time : 0.2861, Train Loss: 0.1223, Train Accuracy: 0.9617, Validation Loss: 0.2024, Validation Accuracy: 0.9230
# 0.31667304039001465
# Epoch [87/100], Time : 0.3167, Train Loss: 0.1220, Train Accuracy: 0.9623, Validation Loss: 0.2011, Validation Accuracy: 0.9225
# 0.30591630935668945
# Epoch [88/100], Time : 0.3059, Train Loss: 0.1217, Train Accuracy: 0.9618, Validation Loss: 0.2023, Validation Accuracy: 0.9225
# 0.3470625877380371
# Epoch [89/100], Time : 0.3471, Train Loss: 0.1221, Train Accuracy: 0.9607, Validation Loss: 0.2012, Validation Accuracy: 0.9230
# 0.3363075256347656
# Epoch [90/100], Time : 0.3363, Train Loss: 0.1210, Train Accuracy: 0.9608, Validation Loss: 0.2028, Validation Accuracy: 0.9215
# 0.3262293338775635
# Epoch [91/100], Time : 0.3262, Train Loss: 0.1200, Train Accuracy: 0.9621, Validation Loss: 0.2014, Validation Accuracy: 0.9220
# 0.334766149520874
# Epoch [92/100], Time : 0.3348, Train Loss: 0.1193, Train Accuracy: 0.9630, Validation Loss: 0.2029, Validation Accuracy: 0.9220
# 0.31899356842041016
# Epoch [93/100], Time : 0.3190, Train Loss: 0.1188, Train Accuracy: 0.9626, Validation Loss: 0.2010, Validation Accuracy: 0.9215
# 0.325897216796875
# Epoch [94/100], Time : 0.3259, Train Loss: 0.1183, Train Accuracy: 0.9642, Validation Loss: 0.2027, Validation Accuracy: 0.9235
# 0.32450342178344727
# Epoch [95/100], Time : 0.3245, Train Loss: 0.1179, Train Accuracy: 0.9627, Validation Loss: 0.2007, Validation Accuracy: 0.9235
# 0.2972126007080078
# Epoch [96/100], Time : 0.2972, Train Loss: 0.1165, Train Accuracy: 0.9655, Validation Loss: 0.2022, Validation Accuracy: 0.9235
# 0.3464043140411377
# Epoch [97/100], Time : 0.3464, Train Loss: 0.1163, Train Accuracy: 0.9628, Validation Loss: 0.2004, Validation Accuracy: 0.9230
# 0.29658985137939453
# Epoch [98/100], Time : 0.2966, Train Loss: 0.1149, Train Accuracy: 0.9644, Validation Loss: 0.2021, Validation Accuracy: 0.9240
# 0.3167421817779541
# Epoch [99/100], Time : 0.3167, Train Loss: 0.1143, Train Accuracy: 0.9636, Validation Loss: 0.1998, Validation Accuracy: 0.9240
# 0.2862377166748047
# Epoch [100/100], Time : 0.2862, Train Loss: 0.1133, Train Accuracy: 0.9653, Validation Loss: 0.2017, Validation Accuracy: 0.9235

# %%
training_acc = history['training_acc']
validation_acc = history['validation_acc']
training_loss = history['training_loss']
validation_loss = history['validation_loss']
epoch_nums = range(1,len(training_acc)+1)

plt.plot(epoch_nums, training_acc, 'bo', label = 'Training acc')
plt.plot(epoch_nums, validation_acc, 'r', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epoch_nums, training_loss, 'bo', label = 'Training loss')
plt.plot(epoch_nums, validation_loss, 'r', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## VGG16 sur Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(C = 1)
logisticRegr.fit(train_features,train_labels)
#balanced test set 
score1 = logisticRegr.score(validation_features, validation_labels)
print("Validation acc = ", score1)
score2 = logisticRegr.score(test_features, test_labels)
print("Test acc = ", score2)
# Out:
# Validation acc =  0.925
# Validation acc =  0.9215
# C:\Users\pattal\.conda\envs\DL\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.kernel_ridge import KernelRidge
import numpy as np

kr = KernelRidge(alpha=1, kernel='rbf')
kr.fit(train_features,train_labels)

y_pred_val = kr.predict(validation_features)
y_pred_test = kr.predict(test_features)

y_pred_val = np.round(y_pred_val)
y_pred_test = np.round(y_pred_test)

val_acc = accuracy_score(validation_labels, y_pred_val)
test_acc = accuracy_score(test_labels, y_pred_test)

print("Validation accuracy: ", val_acc)
print("Test accuracy: ", test_acc)
# Out:
# Validation accuracy:  0.9265
# Test accuracy:  0.934

# %%
from sklearn.ensemble import GradientBoostingClassifier 
clf = GradientBoostingClassifier()
clf.fit(train_features,train_labels)

score1 = clf.score(validation_features, validation_labels)
print("Validation acc = ", score1)
score2 = clf.score(test_features, test_labels)
print("Test acc = ", score2)
# Out:
# Validation acc =  0.886
# Test acc =  0.906

# %% [markdown]
# # Resnet

# %% [markdown]
# Ici nous apportons une autre approche de transfer learning en utilisant le modele Resnet plutot que VGG16

# %% [markdown]
# ## Extraire les features de Resnet

# %%
modelresnet = torchvision.models.resnet18(pretrained=True)
torchsummary.summary(modelresnet, (3,150,150))
# Extraction des caractéristiques
class ResNet(nn.Module):
    def __init__(self, modelresnet):
        super().__init__()
        #garder les couches avant les denses
        self.model = nn.Sequential(*list(modelresnet.children())[:-2])
        
    def forward(self, x):
        return self.model(x)
    
model2 = ResNet(modelresnet)
torchsummary.summary(model2, (3,150,150))
# Out:
# C:\Users\pauli\anaconda3\envs\DL\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# C:\Users\pauli\anaconda3\envs\DL\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 75, 75]           9,408
#        BatchNorm2d-2           [-1, 64, 75, 75]             128
#               ReLU-3           [-1, 64, 75, 75]               0
#          MaxPool2d-4           [-1, 64, 38, 38]               0
#             Conv2d-5           [-1, 64, 38, 38]          36,864
#        BatchNorm2d-6           [-1, 64, 38, 38]             128
#               ReLU-7           [-1, 64, 38, 38]               0
#             Conv2d-8           [-1, 64, 38, 38]          36,864
#        BatchNorm2d-9           [-1, 64, 38, 38]             128
#              ReLU-10           [-1, 64, 38, 38]               0
#        BasicBlock-11           [-1, 64, 38, 38]               0
#            Conv2d-12           [-1, 64, 38, 38]          36,864
#       BatchNorm2d-13           [-1, 64, 38, 38]             128
#              ReLU-14           [-1, 64, 38, 38]               0
#            Conv2d-15           [-1, 64, 38, 38]          36,864
#       BatchNorm2d-16           [-1, 64, 38, 38]             128
#              ReLU-17           [-1, 64, 38, 38]               0
#        BasicBlock-18           [-1, 64, 38, 38]               0
#            Conv2d-19          [-1, 128, 19, 19]          73,728
#       BatchNorm2d-20          [-1, 128, 19, 19]             256
#              ReLU-21          [-1, 128, 19, 19]               0
#            Conv2d-22          [-1, 128, 19, 19]         147,456
#       BatchNorm2d-23          [-1, 128, 19, 19]             256
#            Conv2d-24          [-1, 128, 19, 19]           8,192
#       BatchNorm2d-25          [-1, 128, 19, 19]             256
#              ReLU-26          [-1, 128, 19, 19]               0
#        BasicBlock-27          [-1, 128, 19, 19]               0
#            Conv2d-28          [-1, 128, 19, 19]         147,456
#       BatchNorm2d-29          [-1, 128, 19, 19]             256
#              ReLU-30          [-1, 128, 19, 19]               0
#            Conv2d-31          [-1, 128, 19, 19]         147,456
#       BatchNorm2d-32          [-1, 128, 19, 19]             256
#              ReLU-33          [-1, 128, 19, 19]               0
#        BasicBlock-34          [-1, 128, 19, 19]               0
#            Conv2d-35          [-1, 256, 10, 10]         294,912
#       BatchNorm2d-36          [-1, 256, 10, 10]             512
#              ReLU-37          [-1, 256, 10, 10]               0
#            Conv2d-38          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-39          [-1, 256, 10, 10]             512
#            Conv2d-40          [-1, 256, 10, 10]          32,768
#       BatchNorm2d-41          [-1, 256, 10, 10]             512
#              ReLU-42          [-1, 256, 10, 10]               0
#        BasicBlock-43          [-1, 256, 10, 10]               0
#            Conv2d-44          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-45          [-1, 256, 10, 10]             512
#              ReLU-46          [-1, 256, 10, 10]               0
#            Conv2d-47          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-48          [-1, 256, 10, 10]             512
#              ReLU-49          [-1, 256, 10, 10]               0
#        BasicBlock-50          [-1, 256, 10, 10]               0
#            Conv2d-51            [-1, 512, 5, 5]       1,179,648
#       BatchNorm2d-52            [-1, 512, 5, 5]           1,024
#              ReLU-53            [-1, 512, 5, 5]               0
#            Conv2d-54            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-55            [-1, 512, 5, 5]           1,024
#            Conv2d-56            [-1, 512, 5, 5]         131,072
#       BatchNorm2d-57            [-1, 512, 5, 5]           1,024
#              ReLU-58            [-1, 512, 5, 5]               0
#        BasicBlock-59            [-1, 512, 5, 5]               0
#            Conv2d-60            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-61            [-1, 512, 5, 5]           1,024
#              ReLU-62            [-1, 512, 5, 5]               0
#            Conv2d-63            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-64            [-1, 512, 5, 5]           1,024
#              ReLU-65            [-1, 512, 5, 5]               0
#        BasicBlock-66            [-1, 512, 5, 5]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                 [-1, 1000]         513,000
# ================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 29.16
# Params size (MB): 44.59
# Estimated Total Size (MB): 74.01
# ----------------------------------------------------------------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 75, 75]           9,408
#        BatchNorm2d-2           [-1, 64, 75, 75]             128
#               ReLU-3           [-1, 64, 75, 75]               0
#          MaxPool2d-4           [-1, 64, 38, 38]               0
#             Conv2d-5           [-1, 64, 38, 38]          36,864
#        BatchNorm2d-6           [-1, 64, 38, 38]             128
#               ReLU-7           [-1, 64, 38, 38]               0
#             Conv2d-8           [-1, 64, 38, 38]          36,864
#        BatchNorm2d-9           [-1, 64, 38, 38]             128
#              ReLU-10           [-1, 64, 38, 38]               0
#        BasicBlock-11           [-1, 64, 38, 38]               0
#            Conv2d-12           [-1, 64, 38, 38]          36,864
#       BatchNorm2d-13           [-1, 64, 38, 38]             128
#              ReLU-14           [-1, 64, 38, 38]               0
#            Conv2d-15           [-1, 64, 38, 38]          36,864
#       BatchNorm2d-16           [-1, 64, 38, 38]             128
#              ReLU-17           [-1, 64, 38, 38]               0
#        BasicBlock-18           [-1, 64, 38, 38]               0
#            Conv2d-19          [-1, 128, 19, 19]          73,728
#       BatchNorm2d-20          [-1, 128, 19, 19]             256
#              ReLU-21          [-1, 128, 19, 19]               0
#            Conv2d-22          [-1, 128, 19, 19]         147,456
#       BatchNorm2d-23          [-1, 128, 19, 19]             256
#            Conv2d-24          [-1, 128, 19, 19]           8,192
#       BatchNorm2d-25          [-1, 128, 19, 19]             256
#              ReLU-26          [-1, 128, 19, 19]               0
#        BasicBlock-27          [-1, 128, 19, 19]               0
#            Conv2d-28          [-1, 128, 19, 19]         147,456
#       BatchNorm2d-29          [-1, 128, 19, 19]             256
#              ReLU-30          [-1, 128, 19, 19]               0
#            Conv2d-31          [-1, 128, 19, 19]         147,456
#       BatchNorm2d-32          [-1, 128, 19, 19]             256
#              ReLU-33          [-1, 128, 19, 19]               0
#        BasicBlock-34          [-1, 128, 19, 19]               0
#            Conv2d-35          [-1, 256, 10, 10]         294,912
#       BatchNorm2d-36          [-1, 256, 10, 10]             512
#              ReLU-37          [-1, 256, 10, 10]               0
#            Conv2d-38          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-39          [-1, 256, 10, 10]             512
#            Conv2d-40          [-1, 256, 10, 10]          32,768
#       BatchNorm2d-41          [-1, 256, 10, 10]             512
#              ReLU-42          [-1, 256, 10, 10]               0
#        BasicBlock-43          [-1, 256, 10, 10]               0
#            Conv2d-44          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-45          [-1, 256, 10, 10]             512
#              ReLU-46          [-1, 256, 10, 10]               0
#            Conv2d-47          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-48          [-1, 256, 10, 10]             512
#              ReLU-49          [-1, 256, 10, 10]               0
#        BasicBlock-50          [-1, 256, 10, 10]               0
#            Conv2d-51            [-1, 512, 5, 5]       1,179,648
#       BatchNorm2d-52            [-1, 512, 5, 5]           1,024
#              ReLU-53            [-1, 512, 5, 5]               0
#            Conv2d-54            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-55            [-1, 512, 5, 5]           1,024
#            Conv2d-56            [-1, 512, 5, 5]         131,072
#       BatchNorm2d-57            [-1, 512, 5, 5]           1,024
#              ReLU-58            [-1, 512, 5, 5]               0
#        BasicBlock-59            [-1, 512, 5, 5]               0
#            Conv2d-60            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-61            [-1, 512, 5, 5]           1,024
#              ReLU-62            [-1, 512, 5, 5]               0
#            Conv2d-63            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-64            [-1, 512, 5, 5]           1,024
#              ReLU-65            [-1, 512, 5, 5]               0
#        BasicBlock-66            [-1, 512, 5, 5]               0
# ================================================================
# Total params: 11,176,512
# Trainable params: 11,176,512
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 29.14
# Params size (MB): 42.64
# Estimated Total Size (MB): 72.04
# ----------------------------------------------------------------

# %%
datagen = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size=20

train_dataset = ImageFolder(original_dataset_dir+'/train_another', transform=datagen)
train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=4, shuffle=True)

val_dataset = ImageFolder(original_dataset_dir+'/validation_another', transform=datagen)
val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=4, shuffle=True)

test_dataset = ImageFolder(original_dataset_dir+'/test_another', transform=datagen)
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=4, shuffle=True)

# %%
train_features, train_labels = extract_features(train_loader, 10000, model2, batch_size=batch_size,last_size=5)
validation_features, validation_labels = extract_features(val_loader, 2000, model2, batch_size=batch_size,last_size=5)
test_features, test_labels = extract_features(test_loader, 2000, model2, batch_size=batch_size,last_size=5)

# Reformater les caractéristiques pour être de forme (sample_count, 8192)
train_features = train_features.view(10000, 5 * 5 * 512)
validation_features = validation_features.view(2000, 5 * 5 * 512)
test_features = test_features.view(2000, 5 * 5 * 512)

# %% [markdown]
# ## Resnet sur des modeles de machine learning

# %%
from sklearn.ensemble import GradientBoostingClassifier 
clf = GradientBoostingClassifier()
clf.fit(train_features,train_labels)

score1 = clf.score(validation_features, validation_labels)
print("Validation acc = ", score1)
score2 = clf.score(test_features, test_labels)
print("Test acc = ", score2)
# Out:
# Validation acc =  0.8895
# Test acc =  0.6945

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=20, min_samples_split=200, min_samples_leaf=100)
tree.fit(train_features,train_labels)

y_pred_val = tree.predict(validation_features)
y_pred_test = tree.predict(test_features)

y_pred_val = np.round(y_pred_val)
y_pred_test = np.round(y_pred_test)

val_acc = accuracy_score(validation_labels, y_pred_val)
test_acc = accuracy_score(test_labels, y_pred_test)

print("Validation accuracy: ", val_acc)
print("Test accuracy: ", test_acc)
# Out:
# Validation accuracy:  0.7585
# Test accuracy:  0.588

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(train_features,train_labels)

y_pred_val = knn.predict(validation_features)
y_pred_test = knn.predict(test_features)

y_pred_val = np.round(y_pred_val)
y_pred_test = np.round(y_pred_test)

val_acc = accuracy_score(validation_labels, y_pred_val)
test_acc = accuracy_score(test_labels, y_pred_test)

print("Validation accuracy: ", val_acc)
print("Test accuracy: ", test_acc)
# Out:
# Validation accuracy:  0.6275
# Test accuracy:  0.9235

# %%
from sklearn.kernel_ridge import KernelRidge
import numpy as np

kr = KernelRidge(alpha=1, kernel='rbf')
kr.fit(train_features,train_labels)

from sklearn.metrics import accuracy_score

y_pred_val = kr.predict(validation_features)
y_pred_test = kr.predict(test_features)

y_pred_val = np.round(y_pred_val)
y_pred_test = np.round(y_pred_test)

val_acc = accuracy_score(validation_labels, y_pred_val)
test_acc = accuracy_score(test_labels, y_pred_test)

print("Validation accuracy: ", val_acc)
print("Test accuracy: ", test_acc)
# Out:
# Validation accuracy:  0.9085
# Test accuracy:  0.711

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100)

rf.fit(train_features,train_labels)


y_pred_val = rf.predict(validation_features)
y_pred_test = rf.predict(test_features)

y_pred_val = np.round(y_pred_val)
y_pred_test = np.round(y_pred_test)

val_acc = accuracy_score(validation_labels, y_pred_val)
test_acc = accuracy_score(test_labels, y_pred_test)

print("Validation accuracy: ", val_acc)
print("Test accuracy: ", test_acc)
# Out:
# Validation accuracy:  0.869
# Test accuracy:  0.631

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(C = 1)
logisticRegr.fit(train_features,train_labels)
#balanced test set 
score1 = logisticRegr.score(validation_features, validation_labels)
print("Validation acc = ", score1)
score2 = logisticRegr.score(test_features, test_labels)
print("Test acc = ", score2)
# Out:
# C:\Users\pauli\anaconda3\envs\DL\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Validation acc =  0.919
# Test acc =  0.7025

# %%
from sklearn.svm import SVC

# Instanciation du modèle SVC
svc_model = SVC(kernel='linear')
svc_model.fit(train_features,train_labels)

y_pred_val = svc_model.predict(validation_features)
y_pred_test = svc_model.predict(test_features)

y_pred_val = np.round(y_pred_val)
y_pred_test = np.round(y_pred_test)

val_acc = accuracy_score(validation_labels, y_pred_val)
test_acc = accuracy_score(test_labels, y_pred_test)

print("Validation accuracy: ", val_acc)
print("Test accuracy: ", test_acc)
# Out:
# Validation accuracy:  0.9165
# Test accuracy:  0.703
